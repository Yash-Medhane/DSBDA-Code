# %%
import pandas as pd

df = pd.read_csv('data/housing.csv')
df.head(5)
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.45857             5.682861                   7.009188
# 1       79248.64245             6.002900                   6.730821
# 2       61287.06718             5.865890                   8.512727
# 3       63345.24005             7.188236                   5.586729
# 4       59982.19723             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09      23086.80050  1.059034e+06
# 1                          3.09      40173.07217  1.505891e+06
# 2                          5.13      36882.15940  1.058988e+06
# 3                          3.26      34310.24283  1.260617e+06
# 4                          4.23      26354.10947  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
# a. Subset where income > 5 and avg rooms < 6
a = df[(df['Avg. Area Income'] > 5) & (df['Avg. Area Number of Rooms'] < 6)]
a
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3          63345.24005             7.188236                   5.586729
# 10         80527.47208             8.093513                   5.042747
# 13         73163.66344             6.919535                   5.993188
# 17         61929.07702             4.788550                   5.097010
# 22         64490.65027             4.210323                   5.478088
# ...                ...                  ...                        ...
# 4977       75980.43884             6.583105                   5.914892
# 4978       80393.33950             8.899713                   5.652974
# 4988       67637.84067             7.056673                   5.774409
# 4992       87499.12574             6.403473                   4.836091
# 4997       63390.68689             7.250591                   4.805081
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
# b. Merge with regional lookup (mock example)
region = pd.DataFrame({
    'Address': df['Address'].head(),
    'Region': ['North', 'South', 'East', 'West', 'Central']
})
b = pd.merge(df, region, on='Address', how='left')
b
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
# c. Sort by Price and Area Population
c = df.sort_values(by=['Price', 'Area Population'])
c
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3212       47320.65721             3.558054                   7.006987
# 1271       37971.20757             4.291224                   5.807510
# 1799       60167.67261             4.590613                   3.950973
# 1459       35963.33081             3.438547                   8.264122
# 1661       48735.92451             5.543730                   6.091906
# ...                ...                  ...                        ...
# 1248       94733.97128             7.885829                   7.162373
# 924        83814.10116             8.571797                   7.392164
# 693       107701.74840             7.143522                   8.518608
# 2719      101599.67060             7.798746                   7.480512
# 465        90592.46961             7.700132                   9.708803
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
# d. Transpose summary statistics
d = df.describe().transpose()
d
# Out:
#                                count          mean            std  \
# Avg. Area Income              5000.0  6.858311e+04   10657.991214
# Avg. Area House Age           5000.0  5.977222e+00       0.991456
# Avg. Area Number of Rooms     5000.0  6.987792e+00       1.005833
# Avg. Area Number of Bedrooms  5000.0  3.981330e+00       1.234137
# Area Population               5000.0  3.616352e+04    9925.650114
# Price                         5000.0  1.232073e+06  353117.626584
#
#                                        min            25%           50%  \
# Avg. Area Income              17796.631190   61480.562390  6.880429e+04
# Avg. Area House Age               2.644304       5.322283  5.970429e+00
# Avg. Area Number of Rooms         3.236194       6.299250  7.002902e+00
# Avg. Area Number of Bedrooms      2.000000       3.140000  4.050000e+00
# Area Population                 172.610686   29403.928700  3.619941e+04
# ...

# %%
# e. Pivot table: avg Price across income and house age bins
df['IncomeBin'] = pd.cut(df['Avg. Area Income'], bins=3)
df['AgeBin'] = pd.cut(df['Avg. Area House Age'], bins=3)
e = df.pivot_table(index='IncomeBin', columns='AgeBin', values='Price', aggfunc='mean')
e
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_8920\3991547900.py:4: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   e = df.pivot_table(index='IncomeBin', columns='AgeBin', values='Price', aggfunc='mean')
# AgeBin                   (2.637, 4.936]  (4.936, 7.227]  (7.227, 9.519]
# IncomeBin
# (17706.726, 47765.004]     5.357446e+05    7.335676e+05    8.511272e+05
# (47765.004, 77733.376]     9.271249e+05    1.179243e+06    1.446014e+06
# (77733.376, 107701.748]    1.324374e+06    1.566317e+06    1.824567e+06
