# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the dataset
df = pd.read_csv('data/StudentsPerformance.csv')
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# a. Check for and impute any missing test scores (math, reading, writing)
df['math score'] = df['math score'].fillna(df['math score'].mean())
df['reading score'] = df['reading score'].fillna(df['reading score'].mean())
df['writing score'] = df['writing score'].fillna(df['writing score'].mean())
a = df
a
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      AverageScore PerformanceBand
# 0       72.666667         Average
# 1       82.333333       Excellent
# 2       92.666667       Excellent
# 3       49.333333            Poor
# 4       76.333333         Average
# ..            ...             ...
# 995     94.000000       Excellent
# 996     57.333333            Poor
# 997     65.000000         Average
# 998     74.333333         Average
# 999     83.000000       Excellent
#
# [1000 rows x 10 columns]

# %%
# b. Create an overall AverageScore column
df['AverageScore'] = df[['math score', 'reading score', 'writing score']].mean(axis=1)
b = df
b
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      AverageScore PerformanceBand
# 0       72.666667         Average
# 1       82.333333       Excellent
# 2       92.666667       Excellent
# 3       49.333333            Poor
# 4       76.333333         Average
# ..            ...             ...
# 995     94.000000       Excellent
# 996     57.333333            Poor
# 997     65.000000         Average
# 998     74.333333         Average
# 999     83.000000       Excellent
#
# [1000 rows x 10 columns]

# %%
# c. Bucket students into performance bands (Excellent, Average, Poor)
df['PerformanceBand'] = pd.cut(df['AverageScore'], bins=[0, 60, 80, 100], labels=['Poor', 'Average', 'Excellent'])
c = df
c
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      AverageScore PerformanceBand
# 0       72.666667         Average
# 1       82.333333       Excellent
# 2       92.666667       Excellent
# 3       49.333333            Poor
# 4       76.333333         Average
# ..            ...             ...
# 995     94.000000       Excellent
# 996     57.333333            Poor
# 997     65.000000         Average
# 998     74.333333         Average
# 999     83.000000       Excellent
#
# [1000 rows x 10 columns]

# %%
# d. Check for inconsistent or duplicate student records
duplicates = df[df.duplicated()]
inconsistent = df[df.isna().any(axis=1)]
d = {'duplicates': duplicates, 'inconsistent': inconsistent}
d
# Out:
# {'duplicates': Empty DataFrame
#  Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, AverageScore, PerformanceBand]
#  Index: [],
#  'inconsistent': Empty DataFrame
#  Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, AverageScore, PerformanceBand]
#  Index: []}

# %%
# e. Encode gender, lunch, and test preparation course using Label Encoding
label_encoder = LabelEncoder()
df['gender_encoded'] = label_encoder.fit_transform(df['gender'])
df['lunch_encoded'] = label_encoder.fit_transform(df['lunch'])
df['test preparation course_encoded'] = label_encoder.fit_transform(df['test preparation course'])
e = df
e
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      AverageScore PerformanceBand  gender_encoded  lunch_encoded  \
# 0       72.666667         Average               0              1
# 1       82.333333       Excellent               0              1
# 2       92.666667       Excellent               0              1
# 3       49.333333            Poor               1              0
# 4       76.333333         Average               1              1
# ..            ...             ...             ...            ...
# 995     94.000000       Excellent               0              1
# 996     57.333333            Poor               1              0
# 997     65.000000         Average               0              0
# 998     74.333333         Average               0              1
# 999     83.000000       Excellent               0              0
#
#      test preparation course_encoded
# 0                                  1
# 1                                  0
# 2                                  1
# 3                                  1
# 4                                  1
# ..                               ...
# 995                                0
# 996                                1
# 997                                0
# 998                                0
# 999                                1
#
# [1000 rows x 13 columns]
