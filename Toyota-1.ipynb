# %%
import pandas as pd

df = pd.read_csv('data/Toyota.csv')
df.head(5)
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
# Convert columns to numeric if they are not already
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['KM'] = pd.to_numeric(df['KM'], errors='coerce')
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
# a. Create data subsets (e.g., cars with Price > 10000 and KM < 50000)
a = df[(df['Price'] > 10000) & (df['KM'] < 50000)]
a
# Out:
#       Unnamed: 0  Price   Age       KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90       0.0          0
# 8              8  21500  27.0  19700.0   Petrol  192       0.0          0
# ...          ...    ...   ...      ...      ...  ...       ...        ...
# 1037        1037  10500  58.0  25000.0   Petrol  110       1.0          0
# 1039        1039  10950  59.0  22705.0      NaN  110       1.0          0
# 1041        1041  10900  62.0  17345.0      NaN  110       1.0          0
# 1042        1042  10950  67.0  15535.0   Petrol   86       NaN          1
# 1402        1402  10500   NaN  47400.0   Petrol   86       1.0          0
#
#         CC  Doors  Weight
# 0     2000  three    1165
# 2     2000      3    1165
# 3     2000      3    1165
# 4     2000      3    1170
# 8     1800      3    1185
# ...    ...    ...     ...
# 1037  1600      5    1075
# 1039  1600      5    1075
# 1041  1600      3    1050
# 1042  1300      4    1030
# 1402  1300      5    1040
#
# [359 rows x 11 columns]

# %%
# b. Merge Data (mock merge with a small lookup table on 'FuelType')
fuel_info = pd.DataFrame({
    'FuelType': df['FuelType'].head(),
    'Region': ['North', 'South', 'East', 'West', 'Central']
})
b = pd.merge(df, fuel_info, on='FuelType', how='left')
b
# Out:
#       Unnamed: 0  Price   Age       KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 1              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 2              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 3              0  13500  23.0  46986.0   Diesel   90       1.0          0
# 4              0  13500  23.0  46986.0   Diesel   90       1.0          0
# ...          ...    ...   ...      ...      ...  ...       ...        ...
# 2007        1431   7500   NaN  20544.0   Petrol   86       1.0          0
# 2008        1432  10845  72.0      NaN   Petrol   86       0.0          0
# 2009        1433   8500   NaN  17016.0   Petrol   86       0.0          0
# 2010        1434   7250  70.0      NaN      NaN   86       1.0          0
# 2011        1435   6950  76.0      1.0   Petrol  110       0.0          0
#
#         CC  Doors  Weight   Region
# 0     2000  three    1165    North
# 1     2000  three    1165    South
# 2     2000  three    1165     East
# 3     2000  three    1165     West
# 4     2000  three    1165  Central
# ...    ...    ...     ...      ...
# 2007  1300      3    1025      NaN
# 2008  1300      3    1015      NaN
# 2009  1300      3    1015      NaN
# 2010  1300      3    1015      NaN
# 2011  1600      5    1114      NaN
#
# [2012 rows x 12 columns]

# %%
# c. Sort Data by 'Age' in descending order
c = df.sort_values(by='Age', ascending=False)
c
# Out:
#       Unnamed: 0  Price   Age        KM FuelType   HP  MetColor  Automatic  \
# 1051        1051   6150  80.0  194765.0   Diesel   72       0.0          0
# 1394        1394   7450  80.0   49580.0      NaN  110       1.0          0
# 1385        1385   8250  80.0   52700.0   Petrol  110       0.0          0
# 1062        1062   6750  80.0  160000.0   Petrol   86       0.0          0
# 1369        1369   8250  80.0   57787.0   Petrol   86       0.0          0
# ...          ...    ...   ...       ...      ...  ...       ...        ...
# 1416        1416   8950   NaN   40093.0   Petrol  110       0.0          0
# 1422        1422   7600   NaN   36000.0      NaN  110       1.0          0
# 1427        1427   8950   NaN   29000.0   Petrol   86       1.0          1
# 1431        1431   7500   NaN   20544.0   Petrol   86       1.0          0
# 1433        1433   8500   NaN   17016.0   Petrol   86       0.0          0
#
#         CC Doors  Weight
# 1051  2000     3    1120
# 1394  1600     4    1035
# 1385  1600     3    1050
# 1062  1300     3    1015
# 1369  1300     3    1015
# ...    ...   ...     ...
# 1416  1600     5    1114
# 1422  1600     3    1050
# 1427  1300     3    1045
# 1431  1300     3    1025
# 1433  1300     3    1015
#
# [1436 rows x 11 columns]

# %%
# d. Transposing Data (summary stats)
d = df.describe().transpose()
d
# Out:
#              count          mean           std     min       25%      50%  \
# Unnamed: 0  1436.0    717.500000    414.681806     0.0    358.75    717.5
# Price       1436.0  10730.824513   3626.964585  4350.0   8450.00   9900.0
# Age         1336.0     55.672156     18.589804     1.0     43.00     60.0
# KM          1421.0  68647.239972  37333.023589     1.0  43210.00  63634.0
# MetColor    1286.0      0.674961      0.468572     0.0      0.00      1.0
# Automatic   1436.0      0.055710      0.229441     0.0      0.00      0.0
# CC          1436.0   1566.827994    187.182436  1300.0   1400.00   1600.0
# Weight      1436.0   1072.459610     52.641120  1000.0   1040.00   1070.0
#
#                  75%       max
# Unnamed: 0   1076.25    1435.0
# Price       11950.00   32500.0
# Age            70.00      80.0
# KM          87000.00  243000.0
# MetColor        1.00       1.0
# Automatic       0.00       1.0
# CC           1600.00    2000.0
# Weight       1085.00    1615.0

# %%
# e. Shape and reshape Data (pivot: average Price by FuelType and Automatic)
e = df.pivot_table(index='FuelType', columns='Automatic', values='Price', aggfunc='mean')
e
# Out:
# Automatic             0             1
# FuelType
# CNG         9584.000000           NaN
# Diesel     10889.277778           NaN
# Petrol     10650.113225  11292.054795
